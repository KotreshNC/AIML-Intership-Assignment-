# %% [markdown]
# # Confusing LLM Prompts
#
# This notebook demonstrates how to use `confusing_llm_prompts.py` to generate and test tricky prompts against either OpenAI or a local Hugging Face model.

# %%
from pathlib import Path
from confusing_llm_prompts import build_tricky_prompts, query_openai, query_local_model

prompts = build_tricky_prompts()
print(f'Total prompts: {len(prompts)}')
for item in prompts[:3]:
    print('---')
    print(item['category'])
    print(item['prompt'])

# %%
# Example: use a local Hugging Face model (install transformers and torch first)
# response = query_local_model(prompts[0]['prompt'], local_model='gpt2', max_tokens=100, temperature=0.7)
# print(response)

# Example: use OpenAI if you have OPENAI_API_KEY configured
# response = query_openai(prompts[0]['prompt'], model='gpt-4o-mini', max_tokens=100, temperature=0.7)
# print(response)
